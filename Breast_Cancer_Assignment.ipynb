# %%
# %matplotlib inline

# %%
# Make train and test datasets
from sklearn.cross_validation import train_test_split
import numpy as np
np.random.seed(112)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
X.shape
# Out:
# (506L, 13L)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

# The error metric. In this case, we will use c-stat (aka ROC/AUC)
from sklearn.metrics import roc_auc_score

# An efficient data structure. 
import pandas as pd

# Import the data
X = pd.read_csv("breast_cancer.csv")
y = X.pop("malignant")

# %%
X.describe()
# Out:
#        Unnamed: 0        id number  clump_thickness  uniformity_of_cell_size  \
# count  699.000000       699.000000       699.000000               699.000000
# mean   349.000000   1071704.098712         4.417740                 3.134478
# std    201.928205    617095.729819         2.815741                 3.051459
# min      0.000000     61634.000000         1.000000                 1.000000
# 25%    174.500000    870688.500000         2.000000                 1.000000
# 50%    349.000000   1171710.000000         4.000000                 1.000000
# 75%    523.500000   1238298.000000         6.000000                 5.000000
# max    698.000000  13454352.000000        10.000000                10.000000
#
#        uniformity_of_cell_shape  marginal_adhesion  epithelial_cell_size  \
# count                699.000000         699.000000            699.000000
# mean                   3.207439           2.806867              3.216023
# std                    2.971913           2.855379              2.214300
# min                    1.000000           1.000000              1.000000
# 25%                    1.000000           1.000000              2.000000
# 50%                    1.000000           1.000000              2.000000
# 75%                    5.000000           4.000000              4.000000
# max                   10.000000          10.000000             10.000000
#
#        bare_nuclei  bland_chromatin  normal_nucleoli     mitoses
# count   699.000000       699.000000       699.000000  699.000000
# mean      3.440629         3.437768         2.866953    1.589413
# std       3.665507         2.438364         3.053634    1.715078
# min      -1.000000         1.000000         1.000000    1.000000
# 25%       1.000000         2.000000         1.000000    1.000000
# 50%       1.000000         3.000000         1.000000    1.000000
# 75%       5.000000         5.000000         4.000000    1.000000
# max      10.000000        10.000000        10.000000   10.000000

# %%
#Linear Regression

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
print "R^2:", model.score(X_test, y_test).round(2)

# %%
# Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
print "R^2:", model.score(X_test, y_test).round(2)
# Out:
# R^2: 0.84

# %%
# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)
print "R^2:", model.score(X_test, y_test).round(2)
# Out:
# R^2: 0.91

# %%
# Get just the numeric variables by selecting only the variables that are not "object" datatypes.
numeric_variables = list(X.dtypes[X.dtypes != "object"].index)
X[numeric_variables].head()
# Out:
#    Unnamed: 0  id number  clump_thickness  uniformity_of_cell_size  \
# 0           0    1000025                5                        1
# 1           1    1002945                5                        4
# 2           2    1015425                3                        1
# 3           3    1016277                6                        8
# 4           4    1017023                4                        1
#
#    uniformity_of_cell_shape  marginal_adhesion  epithelial_cell_size  \
# 0                         1                  1                     2
# 1                         4                  5                     7
# 2                         1                  1                     2
# 3                         8                  1                     3
# 4                         1                  3                     2
#
#    bare_nuclei  bland_chromatin  normal_nucleoli  mitoses
# 0            1                3                1        1
# 1           10                3                2        1
# 2            2                3                1        1
# 3            4                3                7        1
# 4            1                3                1        1

# %%
# Let's build our first model. I always have oob_score=True. It is a good idea to increase n_estimators to a number higher than 
# the default. In this case the oob_predictions will be based on a forest of 33 trees. I set random_state=42 so that you all can
# replicate the model exactly.
model = RandomForestRegressor(n_estimators=100, oob_score=True, random_state=42)

# I only use numeric_variables because I have yet to dummy out the categorical variables
model.fit(X[numeric_variables], y)
# Out:
# RandomForestRegressor(bootstrap=True, compute_importances=None,
#            criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#            min_samples_split=2, n_estimators=100, n_jobs=1, oob_score=True,
#            random_state=42, verbose=0)

# %%
model.oob_score_
# Out:
# 0.87175758526125369

# %%
y_oob = model.oob_prediction_
print "c-stat: ", roc_auc_score(y, y_oob).round(2)
# Out:
# c-stat:  0.99

# %%
# Here is a simple function to show descriptive stats on the categorical variables
def describe_categorical(X):
    """
    Just like .describe(), but returns the results for
    categorical variables only.
    """
    from IPython.display import display, HTML
    display(HTML(X[X.columns[X.dtypes == "object"]].describe().to_html()))

# %%
describe_categorical(X)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unique</th>
#     </tr>
#     <tr>
#       <th>top</th>
#     </tr>
#     <tr>
#       <th>freq</th>
#     </tr>
#   </tbody>
# </table>

# %%
# Drop the variables I don't feel like dealing with for this tutorial
X.drop(["Unnamed: 0", "id number"], axis=1, inplace=True)

# %%
categorical_variables = ['clump_thickness', 'bland_chromatin', 'epithelial_cell_size']

for variable in categorical_variables:
    # Fill missing data with the word "Missing"
    X[variable].fillna("Missing", inplace=True)
    # Create array of dummies
    dummies = pd.get_dummies(X[variable], prefix=variable)
    # Update X to include dummies and drop the main variable
    X = pd.concat([X, dummies], axis=1)
    X.drop([variable], axis=1, inplace=True)

# %%
X
# Out:
#      uniformity_of_cell_size  uniformity_of_cell_shape  marginal_adhesion  \
# 0                          1                         1                  1
# 1                          4                         4                  5
# 2                          1                         1                  1
# 3                          8                         8                  1
# 4                          1                         1                  3
# 5                         10                        10                  8
# 6                          1                         1                  1
# 7                          1                         2                  1
# 8                          1                         1                  1
# 9                          2                         1                  1
# 10                         1                         1                  1
# 11                         1                         1                  1
# 12                         3                         3                  3
# 13                         1                         1                  1
# 14                         7                         5                 10
# 15                         4                         6                  4
# 16                         1                         1                  1
# 17                         1                         1                  1
# 18                         7                         7                  6
# 19                         1                         1                  1
# 20                         3                         2                 10
# 21                         5                         5                  3
# 22                         1                         1                  1
# 23                         4                         5                  1
# 24                         1                         1                  1
# 25                         2                         3                  4
# 26                         2                         1                  1
# 27                         1                         1                  1
# 28                         1                         1                  1
# 29                         1                         3                  1
# ..                       ...                       ...                ...
# 669                       10                        10                  8
# 670                       10                         7                  8
# 671                        2                         1                  2
# 672                        1                         1                  1
# 673                        3                         2                  1
# 674                        1                         1                  1
# 675                        1                         4                  1
# 676                        1                         2                  1
# 677                        1                         1                  1
# 678                        1                         1                  1
# 679                        1                         1                  1
# 680                       10                        10                 10
# 681                       10                        10                 10
# 682                        1                         1                  1
# 683                        1                         1                  1
# 684                        1                         1                  1
# 685                        1                         1                  1
# 686                        1                         1                  1
# 27                        0                        0
# 28                        0                        0
# 29                        0                        0
# ..                      ...                      ...
# 669                       0                        0
# 670                       0                        0
# 671                       0                        0
# 672                       0                        0
# 673                       0                        0
# 674                       0                        0
# 675                       0                        0
# 676                       0                        0
# 677                       0                        0
# 678                       0                        0
# 679                       0                        0
# 680                       0                        0
# 681                       0                        0
# 682                       0                        0
# 683                       0                        0
# 684                       0                        0
# 685                       0                        0
# 686                       0                        0
# 687                       0                        0
# 688                       0                        0
# 689                       0                        0
# 690                       0                        0
# 691                       0                        0
# 692                       0                        0
# 693                       0                        0
# 694                       0                        0
# 695                       0                        0
# 696                       0                        0
# 697                       0                        0
# 698                       0                        0
#
# [699 rows x 36 columns]

# %%
# Look at all the columns in the dataset
def printall(X, max_rows=10):
    from IPython.display import display, HTML
    display(HTML(X.to_html(max_rows=max_rows)))
    
printall(X)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uniformity_of_cell_size</th>
#       <th>uniformity_of_cell_shape</th>
#       <th>marginal_adhesion</th>
#       <th>bare_nuclei</th>
#       <th>normal_nucleoli</th>
#       <th>mitoses</th>
#       <th>clump_thickness_1</th>
#       <th>clump_thickness_2</th>
#       <th>clump_thickness_3</th>
#       <th>clump_thickness_4</th>
#       <th>clump_thickness_5</th>
#       <th>clump_thickness_6</th>
#       <th>clump_thickness_7</th>
#       <th>clump_thickness_8</th>
#       <th>clump_thickness_9</th>
#       <th>clump_thickness_10</th>
#       <th>bland_chromatin_1</th>
#       <th>bland_chromatin_2</th>
#       <th>bland_chromatin_3</th>
#       <th>bland_chromatin_4</th>
#       <th>bland_chromatin_5</th>
#       <th>bland_chromatin_6</th>
#       <th>bland_chromatin_7</th>
#       <th>bland_chromatin_8</th>
#       <th>bland_chromatin_9</th>
#       <th>bland_chromatin_10</th>
#       <th>epithelial_cell_size_1</th>
#       <th>epithelial_cell_size_2</th>
#       <th>epithelial_cell_size_3</th>
#       <th>epithelial_cell_size_4</th>
#       <th>epithelial_cell_size_5</th>
#       <th>epithelial_cell_size_6</th>
#       <th>epithelial_cell_size_7</th>
#       <th>epithelial_cell_size_8</th>
#       <th>epithelial_cell_size_9</th>
#       <th>epithelial_cell_size_10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0  </th>
#       <td>  1</td>
#       <td>  1</td>
#       <td> 1</td>
#       <td>  1</td>
#       <td>  1</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>1  </th>
#       <td>  4</td>
#       <td>  4</td>
#       <td> 5</td>
#       <td> 10</td>
#       <td>  2</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>2  </th>
#       <td>  1</td>
#       <td>  1</td>
#       <td> 1</td>
#       <td>  2</td>
#       <td>  1</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>3  </th>
#       <td>  8</td>
#       <td>  8</td>
#       <td> 1</td>
#       <td>  4</td>
#       <td>  7</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>4  </th>
#       <td>  1</td>
#       <td>  1</td>
#       <td> 3</td>
#       <td>  1</td>
#       <td>  1</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>694</th>
#       <td>  1</td>
#       <td>  1</td>
#       <td> 1</td>
#       <td>  2</td>
#       <td>  1</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>695</th>
#       <td>  1</td>
#       <td>  1</td>
#       <td> 1</td>
#       <td>  1</td>
#       <td>  1</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>696</th>
#       <td> 10</td>
#       <td> 10</td>
#       <td> 3</td>
#       <td>  3</td>
#       <td> 10</td>
#       <td> 2</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>697</th>
#       <td>  8</td>
#       <td>  6</td>
#       <td> 4</td>
#       <td>  4</td>
#       <td>  6</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>

# %%
model = RandomForestRegressor(1000, oob_score=True, n_jobs=-1, random_state=42)
model.fit(X, y)
print "C-stat: ", roc_auc_score(y, model.oob_prediction_)
# Out:
# C-stat:  0.99090398449

# %%
model.feature_importances_
# Out:
# array([  5.70735095e-01,   1.69531904e-01,   1.03261029e-02,
#          1.41106398e-01,   2.72783759e-02,   5.76659241e-03,
#          2.28633925e-03,   1.52613663e-04,   1.82885182e-03,
#          7.27926121e-03,   2.50840143e-03,   9.03953752e-03,
#          3.28109043e-03,   4.48681207e-03,   2.12797080e-04,
#          2.81463474e-03,   2.25453661e-03,   1.92797787e-03,
#          3.69794081e-03,   4.22744701e-03,   1.20712710e-03,
#          2.20490162e-04,   1.74154209e-03,   3.47032417e-04,
#          4.05156118e-05,   8.26958219e-05,   1.83587069e-03,
#          2.51989559e-03,   2.03358883e-03,   2.72748496e-03,
#          4.37739560e-03,   4.68026267e-03,   5.83286530e-03,
#          1.11301339e-03,   0.00000000e+00,   4.97510137e-04])

# %%
model = RandomForestRegressor(100, oob_score=True, n_jobs=2, random_state=42)
model.fit(X, y)
print "C-stat: ", roc_auc_score(y, model.oob_prediction_)
# Out:
# C-stat:  0.989780572215

# %%
# Simple version that shows all of the variables
feature_importances = pd.Series(model.feature_importances_, index=X.columns)
feature_importances.sort()
feature_importances.plot(kind="barh", figsize=(7,6));

# %%
# Complex version that shows the summary view

def graph_feature_importances(model, feature_names, autoscale=True, headroom=0.05, width=10, summarized_columns=None):
    """
    By Mike Bernico
    
    Graphs the feature importances of a random decision forest using a horizontal bar chart. 
    Probably works but untested on other sklearn.ensembles.
    
    Parameters
    ----------
    ensemble = Name of the ensemble whose features you would like graphed.
    feature_names = A list of the names of those featurs, displayed on the Y axis.
    autoscale = True (Automatically adjust the X axis size to the largest feature +.headroom) / False = scale from 0 to 1
    headroom = used with autoscale, .05 default
    width=figure width in inches
    summarized_columns = a list of column prefixes to summarize on, for dummy variables (e.g. ["day_"] would summarize all day_ vars
    """
    
    if autoscale:
        x_scale = model.feature_importances_.max()+ headroom
    else:
        x_scale = 1
    
    feature_dict=dict(zip(feature_names, model.feature_importances_))
    
    if summarized_columns: 
        #some dummy columns need to be summarized
        for col_name in summarized_columns: 
            #sum all the features that contain col_name, store in temp sum_value
            sum_value = sum(x for i, x in feature_dict.iteritems() if col_name in i )  
            
            #now remove all keys that are part of col_name
            keys_to_remove = [i for i in feature_dict.keys() if col_name in i ]
            for i in keys_to_remove:
                feature_dict.pop(i)
            #lastly, read the summarized field
            feature_dict[col_name] = sum_value
        
    results = pd.Series(feature_dict.values(), index=feature_dict.keys())
    results.sort(axis=1)
    results.plot(kind="barh", figsize=(width,len(results)/4), xlim=(0,x_scale))
    
graph_feature_importances(model, X.columns, summarized_columns=categorical_variables)

# %%
# %%timeit
model = RandomForestRegressor(1000, oob_score=True, n_jobs=2, random_state=42)
model.fit(X, y)
# Out:
# 1 loops, best of 3: 1.63 s per loop

# %%
# %%timeit
model = RandomForestRegressor(1000, oob_score=True, n_jobs=-1, random_state=42)
model.fit(X, y)
# Out:
# 1 loops, best of 3: 1.63 s per loop

# %%
results = []
n_estimator_options = [30, 50, 100, 200, 500, 1000, 2000]

for trees in n_estimator_options:
    model = RandomForestRegressor(trees, oob_score=True, n_jobs=-1, random_state=42)
    model.fit(X, y)
    print trees, "trees"
    roc = roc_auc_score(y, model.oob_prediction_)
    print "C-stat: ", roc
    results.append(roc)
    print ""
    
pd.Series(results, n_estimator_options).plot();
# Out:
# 30 trees
# C-stat:  0.985830509703
#
# 50
#  trees
# C-stat:  0.986102302995
#
# 100
#  trees
# C-stat:  0.989780572215
#
# 200
#  trees
# C-stat:  0.990093134501
#
# 500
#  trees
# C-stat:  0.990840566055
#
# 1000
#  trees
# C-stat:  0.99090398449
#
# 2000
#  trees
# C-stat:  0.990772617732

# %%
results = []
max_features_options = ["auto", None, "sqrt", "log2", 0.9, 0.2]

for max_features in max_features_options:
    model = RandomForestRegressor(n_estimators=1000, oob_score=True, n_jobs=-1, random_state=42, max_features=max_features)
    model.fit(X, y)
    print max_features, "option"
    roc = roc_auc_score(y, model.oob_prediction_)
    print "C-stat: ", roc
    results.append(roc)
    print ""
    
pd.Series(results, max_features_options).plot(kind="barh", xlim=(.85,1.56));
# Out:
# auto option
# C-stat:  0.99090398449
#
# None
#  option
# C-stat:  0.99090398449
#
# sqrt
#  option
# C-stat:  0.991800902354
#
# log2
#  option
# C-stat:  0.991782782801
#
# 0.9
#  option
# C-stat:  0.990845095943
#
# 0.2
#  option
# C-stat:  0.991298084763

# %%
results = []
min_samples_leaf_options = [2, 4, 6, 7, 8, 9, 10,12 ,14,16]

for min_samples in min_samples_leaf_options:
    model = RandomForestRegressor(n_estimators=1000, 
                                  oob_score=True, 
                                  n_jobs=-1, 
                                  random_state=42, 
                                  max_features="auto", 
                                  min_samples_leaf=min_samples)
    model.fit(X, y)
    print min_samples, "min samples"
    roc = roc_auc_score(y, model.oob_prediction_)
    print "C-stat: ", roc
    results.append(roc)
    print ""
    
pd.Series(results, min_samples_leaf_options).plot();
# Out:
# 2 min samples
# C-stat:  0.98987116998
#
# 4
#  min samples
# C-stat:  0.989128268314
#
# 6
#  min samples
# C-stat:  0.988965192339
#
# 7
#  min samples
# C-stat:  0.9887115186
#
# 8
#  min samples
# C-stat:  0.988648100165
#
# 9
#  min samples
# C-stat:  0.98858468173
#
# 10
#  min samples
# C-stat:  0.988521263295
#
# 12
#  min samples
# C-stat:  0.988521263295
#
# 14
#  min samples
# C-stat:  0.988032035369
#
# 16
#  min samples
# C-stat:  0.987687763866

# %%
model = RandomForestRegressor(n_estimators=1000, 
                              oob_score=True, 
                              n_jobs=-1, 
                              random_state=42, 
                              max_features="auto", 
                              min_samples_leaf=2)
model.fit(X, y)
roc = roc_auc_score(y, model.oob_prediction_)
print "C-stat: ", roc
# Out:
# C-stat:  0.98987116998

# %%
model = RandomForestRegressor(n_estimators=3456, 
                              oob_score=True, 
                              n_jobs=-1, 
                              random_state=42, 
                              max_features=0.98, 
                              min_samples_leaf=2)
model.fit(X, y)
roc = roc_auc_score(y, model.oob_prediction_)
print "C-stat: ", roc
# Out:
# C-stat:  0.989535958253

# %%
model = RandomForestRegressor(n_estimators=3456, 
                              oob_score=True, 
                              n_jobs=2, 
                              random_state=42, 
                              max_features=None, 
                              min_samples_leaf=2)
model.fit(X, y)
roc = roc_auc_score(y, model.oob_prediction_)
print "C-stat: ", roc
# Out:
# C-stat:  0.989535958253

# %%
model = RandomForestRegressor(n_estimators=3456, 
                              oob_score=True, 
                              n_jobs=-1, 
                              random_state=42, 
                              max_features="sqrt", 
                              min_samples_leaf=1)
model.fit(X, y)
roc = roc_auc_score(y, model.oob_prediction_)
print "C-stat: ", roc
# Out:
# C-stat:  0.991891500118

# %%
model = RandomForestRegressor(n_estimators=2002, 
                              oob_score=True, 
                              n_jobs=-1, 
                              random_state=42, 
                              max_features="auto", 
                              min_samples_leaf=2)
model.fit(X, y)
roc = roc_auc_score(y, model.oob_prediction_)
print "C-stat: ", roc
# Out:
# C-stat:  0.989563137582

# %%
model = RandomForestRegressor(n_estimators=100, 
                              oob_score=True, 
                              n_jobs=2, 
                              random_state=42, 
                              max_features=0.98, 
                              min_samples_leaf=2)
model.fit(X, y)
roc = roc_auc_score(y, model.oob_prediction_)
print "C-stat: ", roc
# Out:
# C-stat:  0.990292449582

# %%
#Final Model for RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, 
                              oob_score=True, 
                              n_jobs=-1, 
                              random_state=42, 
                              max_features="sqrt", 
                              min_samples_leaf=2)
model.fit(X, y)
roc = roc_auc_score(y, model.oob_prediction_)
print "C-stat: ", roc
# Out:
# C-stat:  0.992185942851

# %%
model = RandomForestRegressor(n_estimators=100, 
                              oob_score=True, 
                              n_jobs=2, 
                              random_state=42, 
                              max_features=None, 
                              min_samples_leaf=2)
model.fit(X, y)
roc = roc_auc_score(y, model.oob_prediction_)
print "C-stat: ", roc
# Out:
# C-stat:  0.991212016887

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
import pandas as pd
X = pd.read_csv("breast_cancer.csv")
y = X.pop("malignant")

# %%
X.describe()
# Out:
#        Unnamed: 0        id number  clump_thickness  uniformity_of_cell_size  \
# count  699.000000       699.000000       699.000000               699.000000
# mean   349.000000   1071704.098712         4.417740                 3.134478
# std    201.928205    617095.729819         2.815741                 3.051459
# min      0.000000     61634.000000         1.000000                 1.000000
# 25%    174.500000    870688.500000         2.000000                 1.000000
# 50%    349.000000   1171710.000000         4.000000                 1.000000
# 75%    523.500000   1238298.000000         6.000000                 5.000000
# max    698.000000  13454352.000000        10.000000                10.000000
#
#        uniformity_of_cell_shape  marginal_adhesion  epithelial_cell_size  \
# count                699.000000         699.000000            699.000000
# mean                   3.207439           2.806867              3.216023
# std                    2.971913           2.855379              2.214300
# min                    1.000000           1.000000              1.000000
# 25%                    1.000000           1.000000              2.000000
# 50%                    1.000000           1.000000              2.000000
# 75%                    5.000000           4.000000              4.000000
# max                   10.000000          10.000000             10.000000
#
#        bare_nuclei  bland_chromatin  normal_nucleoli     mitoses
# count   699.000000       699.000000       699.000000  699.000000
# mean      3.440629         3.437768         2.866953    1.589413
# std       3.665507         2.438364         3.053634    1.715078
# min      -1.000000         1.000000         1.000000    1.000000
# 25%       1.000000         2.000000         1.000000    1.000000
# 50%       1.000000         3.000000         1.000000    1.000000
# 75%       5.000000         5.000000         4.000000    1.000000
# max      10.000000        10.000000        10.000000   10.000000

# %%
from sklearn.cross_validation import train_test_split
import numpy as np
np.random.seed(100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25)

# %%
model = RandomForestClassifier(n_estimators=1000, oob_score=True, random_state=42)
model.fit(X_train, y_train)

roc = roc_auc_score(y_test, model.predict(X_test))
print "C-stat: ", roc
# Out:
# C-stat:  0.942857142857

# %%
results = []
n_estimator_options = [20, 50, 70, 100, 400, 500, 1000, 1500,2000]

for trees in n_estimator_options:
    model = RandomForestClassifier(trees, oob_score=True, n_jobs=-1, random_state=42)
    model.fit(X_train, y_train)
    print trees, "trees"
    roc = roc_auc_score(y_test, model.predict(X_test))
    print "C-stat: ", roc
    results.append(roc)
    print ""
    
pd.Series(results, n_estimator_options).plot();
# Out:
# 20 trees
# C-stat:
#  0.945238095238
#
# 50
#  trees
# C-stat:
#  0.945238095238
#
# 70
#  trees
# C-stat:
#  0.95
#
# 100
#  trees
# C-stat:
#  0.942857142857
#
# 400
#  trees
# C-stat:
#  0.942857142857
#
# 500
#  trees
# C-stat:
#  0.942857142857
#
# 1000
#  trees
# C-stat:
#  0.942857142857
#
# 1500
#  trees
# C-stat:
#  0.942857142857
#
# 2000
#  trees
# C-stat:
#  0.942857142857

# %%
results = []
max_features_options = ["auto", None, "sqrt", "log2", 0.9, 0.2]

for max_features in max_features_options:
    model = RandomForestClassifier(n_estimators=1000, oob_score=True, n_jobs=2, random_state=42, max_features=max_features)
    model.fit(X_train, y_train)
    print max_features, "option"
    roc = roc_auc_score(y_test, model.predict(X_test))
    print "C-stat: ", roc
    results.append(roc)
    print ""
    
pd.Series(results, max_features_options).plot(kind="barh", xlim=(.85,.99));
# Out:
# auto option
# C-stat:
#  0.942857142857
#
# None
#  option
# C-stat:
#  0.930952380952
#
# sqrt
#  option
# C-stat:
#  0.942857142857
#
# log2
#  option
# C-stat:
#  0.942857142857
#
# 0.9
#  option
# C-stat:
#  0.930952380952
#
# 0.2
#  option
# C-stat:
#  0.95

# %%
#Final Model for Random Forest Classifier
model = RandomForestClassifier(n_estimators=100, 
                              oob_score=True, 
                              n_jobs=2, 
                              random_state=42, 
                              max_features=0.2, 
                              min_samples_leaf=5)
model.fit(X_train, y_train)
roc = roc_auc_score(y_test, model.predict(X_test)).round(2)
print "C-stat: ", roc
# Out:
# C-stat:  0.95

# %%
model = RandomForestClassifier(n_estimators=1000, 
                              oob_score=True, 
                              n_jobs=1, 
                              random_state=42, 
                              max_features="log2", 
                              min_samples_leaf=5)
model.fit(X_train, y_train)
roc = roc_auc_score(y_test, model.predict(X_test)).round(2)
print "C-stat: ", roc
# Out:
# C-stat:  0.94

# %%
from sklearn.metrics import classification_report
print classification_report(model.predict(X_test), y_test)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.93      0.96      0.95       102
#           1       0.94      0.90      0.92        73
#
# avg / total       0.94      0.94      0.94       175
